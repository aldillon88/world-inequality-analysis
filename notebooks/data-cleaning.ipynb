# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio

# Set the default template to dark
pio.templates.default = "plotly_dark"

# %%
countries_path = '../data/WID_countries.csv'
countries_df = pd.read_csv(filepath_or_buffer=countries_path, delimiter=';')
countries_df.head(2)
# Out:
#   alpha2                 titlename             shortname  region  \
# 0     AD                   Andorra               Andorra  Europe
# 1     AE  the United Arab Emirates  United Arab Emirates    Asia
#
#           region2
# 0  Western Europe
# 1       West Asia

# %%
af_path = '../data/WID_data_AF.csv'
af = pd.read_csv(filepath_or_buffer=af_path, delimiter=';')
af.head(2)
# Out:
#   country    variable percentile  year      value  age pop
# 0      AF  ehfghgi999     p0p100  1980  13.085614  999   i
# 1      AF  ehfghgi999     p0p100  1981  12.898053  999   i

# %%
af_meta_path = '../data/WID_metadata_AF.csv'
af_meta = pd.read_csv(af_meta_path, delimiter=';')
af_meta.head(2)
# Out:
#   country    variable  age pop  countryname             shortname simpledes  \
# 0      AF  acitgri992  992   i  Afghanistan  Corporate income tax       NaN
# 1      AF  acitgri999  999   i  Afghanistan  Corporate income tax       NaN
#
#   technicaldes shorttype                                           longtype  \
# 0          NaN   Average  Average income or wealth between two percentil...
# 1          NaN   Average  Average income or wealth between two percentil...
#
#       shortpop                                            longpop  shortage  \
# 0  individuals  The base unit is the individual (rather than t...    Adults
# 1  individuals  The base unit is the individual (rather than t...  All Ages
#
#                                              longage unit source method  \
# 0  The population is comprised of individuals ove...  AFN    NaN    NaN
# 1  The population is comprised of individuals of ...  AFN    NaN    NaN
#
#   extrapolation data_points
# 0           NaN         NaN
# 1           NaN         NaN

# %%
print(f"The data file contains {af.shape[1]} columns and {af.shape[0]} rows")
print(f"The metadata file contains {af_meta.shape[1]} columns and {af_meta.shape[0]} rows")
print(f"There are {af.variable.nunique()} and {af_meta.variable.nunique()} unique values for 'variable' in the data and metadata files respectively.")
# Out:
# The data file contains 7 columns and 191381 rows
# The metadata file contains 19 columns and 552 rows
# There are 552 and 552 unique values for 'variable' in the data and metadata files respectively.

# %%
cols = af_meta.columns
nulls = [val for val in af_meta.isna().sum().values]
unique_vals = [af_meta[col].nunique() for col in af_meta.columns]

summary_dict = {
    'cols': cols,
    'no_of_nulls': nulls,
    'no_of_unique': unique_vals
}

summary = pd.DataFrame(summary_dict)
summary.set_index('cols', inplace=True)
summary
# Out:
#                no_of_nulls  no_of_unique
# cols
# country                  0             1
# variable                 0           552
# age                      0            38
# pop                      0             4
# countryname              0             1
# shortname                0           136
# simpledes              342            32
# technicaldes           414            35
# shorttype                0            14
# longtype                 0            14
# shortpop                 0             4
# longpop                  0             4
# shortage                 0            38
# longage                  0            38
# unit                    11             8
# source                 340            13
# method                 368            31
# extrapolation          500             5
# data_points            546             1

# %%
df = pd.merge(left=af, right=af_meta, how='left', on=['country', 'variable'])

# %%
gdp = df[(df['shortname'] == 'Gross domestic product') & (df['unit'] == '% of national income')][['shortname', 'year', 'value', 'shortage', 'shorttype', 'longtype', 'unit']].copy()
total_pop = df[(df['shortname'] == 'Population') & (df['shortpop'] == 'individuals') & (df['shortage'] == 'All Ages')][['year', 'value', 'shortname']]
total_pop.head(1)
# Out:
#         year      value   shortname
# 143943  1950  7480461.0  Population

# %%
shortname_list = [
    'Defense',
    'Economic affairs',
    'Education',
    'Environmental protection',
    'Health',
    'Housing and community amenities',
    'Public order and safety',
    'Recreation and culture',
    'Social protection'
]

cols_to_keep = ['year', 'value', 'shortname']

a = df[(df['shortname'].isin(shortname_list)) & (df['shorttype'] == 'Total')][cols_to_keep]

total_pop = df[(df['shortname'] == 'Population') & (df['shortpop'] == 'individuals') & (df['shortage'] == 'All Ages')][['year', 'value']]
fx = df.loc[df['shortname'] == 'PPP conversion factor, LCU per USD'][['year', 'value']].rename(columns={'value': 'local_currency_per_usd'})

# %%
fig = go.Figure()

for _, group in a.groupby('shortname'):
    data = group.merge(total_pop, how='inner', on='year', suffixes=('', '_pop')).merge(fx, how='inner', on='year')
    data['per_capita_local'] = data['value'] / data['value_pop']
    data['per_capita_usd'] = data['per_capita_local'] / data['local_currency_per_usd']

    name = data['shortname'].unique()[0]
    fig.add_trace(
        go.Scatter(
            x=data['year'],
            y=data['per_capita_usd'],
            name=name,
            mode='lines+markers'
        )
    )

fig.update_layout(
    title='Per capita public spending'
)

fig.show()

# %%
cols = ['shorttype', 'longtype', 'method']
info = df.loc[df['shortname'] == 'Market exchange rate, LCU per USD'][cols]
for col in cols:
    print(info[col].unique())
# Out:
# ['Exchange rates']
# ['Exchange rate series']
# [nan]

# %%
x = df.loc[df['shortname'] == 'PPP conversion factor, LCU per USD']#[['year', 'value']]
x['unit'].unique()
# Out:
# array(['local currency per foreign currency'], dtype=object)

# %%
x
# Out:
#        country    variable percentile  year      value  age_x pop_x  age_y  \
# 147001      AF  xlcuspi999     p0p100  1970   0.008475    999     i    999
# 147002      AF  xlcuspi999     p0p100  1971   0.008066    999     i    999
# 147003      AF  xlcuspi999     p0p100  1972   0.008071    999     i    999
# 147004      AF  xlcuspi999     p0p100  1973   0.008057    999     i    999
# 147005      AF  xlcuspi999     p0p100  1974   0.008524    999     i    999
# 147006      AF  xlcuspi999     p0p100  1975   0.008284    999     i    999
# 147007      AF  xlcuspi999     p0p100  1976   0.008056    999     i    999
# 147008      AF  xlcuspi999     p0p100  1977   0.008915    999     i    999
# 147009      AF  xlcuspi999     p0p100  1978   0.008942    999     i    999
# 147010      AF  xlcuspi999     p0p100  1979   0.009093    999     i    999
# 147011      AF  xlcuspi999     p0p100  1980   0.008752    999     i    999
# 147012      AF  xlcuspi999     p0p100  1981   0.008355    999     i    999
# 147013      AF  xlcuspi999     p0p100  1982   0.007892    999     i    999
# 147014      AF  xlcuspi999     p0p100  1983   0.007238    999     i    999
# 147015      AF  xlcuspi999     p0p100  1984   0.006735    999     i    999
# 147016      AF  xlcuspi999     p0p100  1985   0.006414    999     i    999
# 147017      AF  xlcuspi999     p0p100  1986   0.006124    999     i    999
# 147018      AF  xlcuspi999     p0p100  1987   0.005793    999     i    999
# 147019      AF  xlcuspi999     p0p100  1988   0.005583    999     i    999
# 147020      AF  xlcuspi999     p0p100  1989   0.006846    999     i    999
# 147021      AF  xlcuspi999     p0p100  1990   0.007645    999     i    999
# 147022      AF  xlcuspi999     p0p100  1991   0.007781    999     i    999
# 147023      AF  xlcuspi999     p0p100  1992   0.007807    999     i    999
# 147024      AF  xlcuspi999     p0p100  1993   0.007797    999     i    999
# 147025      AF  xlcuspi999     p0p100  1994   0.053001    999     i    999
# 147026      AF  xlcuspi999     p0p100  1995   0.114744    999     i    999
# 147027      AF  xlcuspi999     p0p100  1996   0.329804    999     i    999
# 147028      AF  xlcuspi999     p0p100  1997   0.446234    999     i    999
# 147029      AF  xlcuspi999     p0p100  1998   0.463645    999     i    999
# 147030      AF  xlcuspi999     p0p100  1999   5.554657    999     i    999
# 147031      AF  xlcuspi999     p0p100  2000   8.948309    999     i    999
# 147032      AF  xlcuspi999     p0p100  2001   9.989081    999     i    999
# 147033      AF  xlcuspi999     p0p100  2002   7.781159    999     i    999
# 147034      AF  xlcuspi999     p0p100  2003   7.547736    999     i    999
# 147035      AF  xlcuspi999     p0p100  2004   7.996284    999     i    999
# 147036      AF  xlcuspi999     p0p100  2005   8.601033    999     i    999
# 147037      AF  xlcuspi999     p0p100  2006   8.861811    999     i    999
# 147038      AF  xlcuspi999     p0p100  2007   9.305287    999     i    999
# 147039      AF  xlcuspi999     p0p100  2008  10.144547    999     i    999
# 147040      AF  xlcuspi999     p0p100  2009  10.298305    999     i    999
# 147041      AF  xlcuspi999     p0p100  2010  11.307911    999     i    999
# 147042      AF  xlcuspi999     p0p100  2011  12.316777    999     i    999
# 147043      AF  xlcuspi999     p0p100  2012  13.238716    999     i    999
# 147044      AF  xlcuspi999     p0p100  2013  13.624120    999     i    999
# 147045      AF  xlcuspi999     p0p100  2014  13.385880    999     i    999
# 147046      AF  xlcuspi999     p0p100  2015  13.756779    999     i    999
# 147047      AF  xlcuspi999     p0p100  2016  14.336479    999     i    999
# 147048      AF  xlcuspi999     p0p100  2017  14.560037    999     i    999
# 147049      AF  xlcuspi999     p0p100  2018  14.670278    999     i    999
# 147050      AF  xlcuspi999     p0p100  2019  14.530249    999     i    999
# 147051      AF  xlcuspi999     p0p100  2020  14.797744    999     i    999
# 147052      AF  xlcuspi999     p0p100  2021  14.587942    999     i    999
# 147053      AF  xlcuspi999     p0p100  2022  14.717614    999     i    999
# 147054      AF  xlcuspi999     p0p100  2023  15.335023    999     i    999
#
#        pop_y  countryname  ...              longtype     shortpop  \
# 147001     i  Afghanistan  ...  Exchange rate series  individuals
# 147002     i  Afghanistan  ...  Exchange rate series  individuals
# 147003     i  Afghanistan  ...  Exchange rate series  individuals
# 147004     i  Afghanistan  ...  Exchange rate series  individuals
# 147005     i  Afghanistan  ...  Exchange rate series  individuals
# 147006     i  Afghanistan  ...  Exchange rate series  individuals
# 147007     i  Afghanistan  ...  Exchange rate series  individuals
# 147008     i  Afghanistan  ...  Exchange rate series  individuals
# 147009     i  Afghanistan  ...  Exchange rate series  individuals
# 147010     i  Afghanistan  ...  Exchange rate series  individuals
# 147011     i  Afghanistan  ...  Exchange rate series  individuals
# 147012     i  Afghanistan  ...  Exchange rate series  individuals
# 147013     i  Afghanistan  ...  Exchange rate series  individuals
# 147014     i  Afghanistan  ...  Exchange rate series  individuals
# 147015     i  Afghanistan  ...  Exchange rate series  individuals
# 147016     i  Afghanistan  ...  Exchange rate series  individuals
# 147017     i  Afghanistan  ...  Exchange rate series  individuals
# 147018     i  Afghanistan  ...  Exchange rate series  individuals
# 147019     i  Afghanistan  ...  Exchange rate series  individuals
# 147020     i  Afghanistan  ...  Exchange rate series  individuals
# 147021     i  Afghanistan  ...  Exchange rate series  individuals
# 147022     i  Afghanistan  ...  Exchange rate series  individuals
# 147023     i  Afghanistan  ...  Exchange rate series  individuals
# 147024     i  Afghanistan  ...  Exchange rate series  individuals
# 147025     i  Afghanistan  ...  Exchange rate series  individuals
# 147026     i  Afghanistan  ...  Exchange rate series  individuals
# 147027     i  Afghanistan  ...  Exchange rate series  individuals
# 147028     i  Afghanistan  ...  Exchange rate series  individuals
# 147029     i  Afghanistan  ...  Exchange rate series  individuals
# 147030     i  Afghanistan  ...  Exchange rate series  individuals
# 147031     i  Afghanistan  ...  Exchange rate series  individuals
# 147032     i  Afghanistan  ...  Exchange rate series  individuals
# 147033     i  Afghanistan  ...  Exchange rate series  individuals
# 147034     i  Afghanistan  ...  Exchange rate series  individuals
# 147035     i  Afghanistan  ...  Exchange rate series  individuals
# 147036     i  Afghanistan  ...  Exchange rate series  individuals
# 147037     i  Afghanistan  ...  Exchange rate series  individuals
# 147038     i  Afghanistan  ...  Exchange rate series  individuals
# 147039     i  Afghanistan  ...  Exchange rate series  individuals
# 147040     i  Afghanistan  ...  Exchange rate series  individuals
# 147041     i  Afghanistan  ...  Exchange rate series  individuals
# 147042     i  Afghanistan  ...  Exchange rate series  individuals
# 147043     i  Afghanistan  ...  Exchange rate series  individuals
# 147044     i  Afghanistan  ...  Exchange rate series  individuals
# 147045     i  Afghanistan  ...  Exchange rate series  individuals
# 147046     i  Afghanistan  ...  Exchange rate series  individuals
# 147047     i  Afghanistan  ...  Exchange rate series  individuals
# 147048     i  Afghanistan  ...  Exchange rate series  individuals
# 147049     i  Afghanistan  ...  Exchange rate series  individuals
# 147050     i  Afghanistan  ...  Exchange rate series  individuals
# 147051     i  Afghanistan  ...  Exchange rate series  individuals
# 147052     i  Afghanistan  ...  Exchange rate series  individuals
# 147053     i  Afghanistan  ...  Exchange rate series  individuals
# 147054     i  Afghanistan  ...  Exchange rate series  individuals
#
#                                                   longpop  shortage  \
# 147001  The base unit is the individual (rather than t...  All Ages
# 147002  The base unit is the individual (rather than t...  All Ages
# 147003  The base unit is the individual (rather than t...  All Ages
# 147004  The base unit is the individual (rather than t...  All Ages
# 147005  The base unit is the individual (rather than t...  All Ages
# 147006  The base unit is the individual (rather than t...  All Ages
# 147007  The base unit is the individual (rather than t...  All Ages
# 147008  The base unit is the individual (rather than t...  All Ages
# 147009  The base unit is the individual (rather than t...  All Ages
# 147010  The base unit is the individual (rather than t...  All Ages
# 147011  The base unit is the individual (rather than t...  All Ages
# 147012  The base unit is the individual (rather than t...  All Ages
# 147013  The base unit is the individual (rather than t...  All Ages
# 147014  The base unit is the individual (rather than t...  All Ages
# 147015  The base unit is the individual (rather than t...  All Ages
# 147016  The base unit is the individual (rather than t...  All Ages
# 147017  The base unit is the individual (rather than t...  All Ages
# 147018  The base unit is the individual (rather than t...  All Ages
# 147019  The base unit is the individual (rather than t...  All Ages
# 147020  The base unit is the individual (rather than t...  All Ages
# 147021  The base unit is the individual (rather than t...  All Ages
# 147022  The base unit is the individual (rather than t...  All Ages
# 147023  The base unit is the individual (rather than t...  All Ages
# 147024  The base unit is the individual (rather than t...  All Ages
# 147025  The base unit is the individual (rather than t...  All Ages
# 147026  The base unit is the individual (rather than t...  All Ages
# 147027  The base unit is the individual (rather than t...  All Ages
# 147028  The base unit is the individual (rather than t...  All Ages
# 147029  The base unit is the individual (rather than t...  All Ages
# 147030  The base unit is the individual (rather than t...  All Ages
# 147031  The base unit is the individual (rather than t...  All Ages
# 147032  The base unit is the individual (rather than t...  All Ages
# 147033  The base unit is the individual (rather than t...  All Ages
# 147034  The base unit is the individual (rather than t...  All Ages
# 147035  The base unit is the individual (rather than t...  All Ages
# 147036  The base unit is the individual (rather than t...  All Ages
# 147037  The base unit is the individual (rather than t...  All Ages
# 147038  The base unit is the individual (rather than t...  All Ages
# 147039  The base unit is the individual (rather than t...  All Ages
# 147040  The base unit is the individual (rather than t...  All Ages
# 147041  The base unit is the individual (rather than t...  All Ages
# 147042  The base unit is the individual (rather than t...  All Ages
# 147043  The base unit is the individual (rather than t...  All Ages
# 147044  The base unit is the individual (rather than t...  All Ages
# 147045  The base unit is the individual (rather than t...  All Ages
# 147046  The base unit is the individual (rather than t...  All Ages
# 147047  The base unit is the individual (rather than t...  All Ages
# 147048  The base unit is the individual (rather than t...  All Ages
# 147049  The base unit is the individual (rather than t...  All Ages
# 147050  The base unit is the individual (rather than t...  All Ages
# 147051  The base unit is the individual (rather than t...  All Ages
# 147052  The base unit is the individual (rather than t...  All Ages
# 147053  The base unit is the individual (rather than t...  All Ages
# 147054  The base unit is the individual (rather than t...  All Ages
#
#                                                   longage  \
# 147001  The population is comprised of individuals of ...
# 147002  The population is comprised of individuals of ...
# 147003  The population is comprised of individuals of ...
# 147004  The population is comprised of individuals of ...
# 147005  The population is comprised of individuals of ...
# 147006  The population is comprised of individuals of ...
# 147007  The population is comprised of individuals of ...
# 147008  The population is comprised of individuals of ...
# 147009  The population is comprised of individuals of ...
# 147010  The population is comprised of individuals of ...
# 147011  The population is comprised of individuals of ...
# 147012  The population is comprised of individuals of ...
# 147013  The population is comprised of individuals of ...
# 147014  The population is comprised of individuals of ...
# 147015  The population is comprised of individuals of ...
# 147016  The population is comprised of individuals of ...
# 147017  The population is comprised of individuals of ...
# 147018  The population is comprised of individuals of ...
# 147019  The population is comprised of individuals of ...
# 147020  The population is comprised of individuals of ...
# 147021  The population is comprised of individuals of ...
# 147022  The population is comprised of individuals of ...
# 147023  The population is comprised of individuals of ...
# 147024  The population is comprised of individuals of ...
# 147025  The population is comprised of individuals of ...
# 147026  The population is comprised of individuals of ...
# 147027  The population is comprised of individuals of ...
# 147028  The population is comprised of individuals of ...
# 147029  The population is comprised of individuals of ...
# 147030  The population is comprised of individuals of ...
# 147031  The population is comprised of individuals of ...
# 147032  The population is comprised of individuals of ...
# 147033  The population is comprised of individuals of ...
# 147034  The population is comprised of individuals of ...
# 147035  The population is comprised of individuals of ...
# 147036  The population is comprised of individuals of ...
# 147037  The population is comprised of individuals of ...
# 147038  The population is comprised of individuals of ...
# 147039  The population is comprised of individuals of ...
# 147040  The population is comprised of individuals of ...
# 147041  The population is comprised of individuals of ...
# 147042  The population is comprised of individuals of ...
# 147043  The population is comprised of individuals of ...
# 147044  The population is comprised of individuals of ...
# 147045  The population is comprised of individuals of ...
# 147046  The population is comprised of individuals of ...
# 147047  The population is comprised of individuals of ...
# 147048  The population is comprised of individuals of ...
# 147049  The population is comprised of individuals of ...
# 147050  The population is comprised of individuals of ...
# 147051  The population is comprised of individuals of ...
# 147052  The population is comprised of individuals of ...
# 147053  The population is comprised of individuals of ...
# 147054  The population is comprised of individuals of ...
#
#                                        unit  \
# 147001  local currency per foreign currency
# 147002  local currency per foreign currency
# 147003  local currency per foreign currency
# 147004  local currency per foreign currency
# 147005  local currency per foreign currency
# 147006  local currency per foreign currency
# 147007  local currency per foreign currency
# 147008  local currency per foreign currency
# 147009  local currency per foreign currency
# 147010  local currency per foreign currency
# 147011  local currency per foreign currency
# 147012  local currency per foreign currency
# 147013  local currency per foreign currency
# 147014  local currency per foreign currency
# 147015  local currency per foreign currency
# 147016  local currency per foreign currency
# 147017  local currency per foreign currency
# 147018  local currency per foreign currency
# 147019  local currency per foreign currency
# 147020  local currency per foreign currency
# 147021  local currency per foreign currency
# 147022  local currency per foreign currency
# 147023  local currency per foreign currency
# 147024  local currency per foreign currency
# 147025  local currency per foreign currency
# 147026  local currency per foreign currency
# 147027  local currency per foreign currency
# 147028  local currency per foreign currency
# 147029  local currency per foreign currency
# 147030  local currency per foreign currency
# 147031  local currency per foreign currency
# 147032  local currency per foreign currency
# 147033  local currency per foreign currency
# 147034  local currency per foreign currency
# 147035  local currency per foreign currency
# 147036  local currency per foreign currency
# 147037  local currency per foreign currency
# 147038  local currency per foreign currency
# 147039  local currency per foreign currency
# 147040  local currency per foreign currency
# 147041  local currency per foreign currency
# 147042  local currency per foreign currency
# 147043  local currency per foreign currency
# 147044  local currency per foreign currency
# 147045  local currency per foreign currency
# 147046  local currency per foreign currency
# 147047  local currency per foreign currency
# 147048  local currency per foreign currency
# 147049  local currency per foreign currency
# 147050  local currency per foreign currency
# 147051  local currency per foreign currency
# 147052  local currency per foreign currency
# 147053  local currency per foreign currency
# 147054  local currency per foreign currency
#
#                                                    source  \
# 147001  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147002  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147003  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147004  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147005  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147006  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147007  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147008  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147009  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147010  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147011  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147012  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147013  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147014  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147015  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147016  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147017  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147018  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147019  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147020  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147021  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147022  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147023  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147024  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147025  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147026  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147027  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147028  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147029  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147030  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147031  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147032  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147033  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147034  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147035  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147036  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147037  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147038  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147039  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147040  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147041  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147042  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147043  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147044  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147045  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147046  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147047  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147048  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147049  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147050  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147051  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147052  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147053  [URL][URL_LINK]http://data.worldbank.org/[/URL...
# 147054  [URL][URL_LINK]http://data.worldbank.org/[/URL...
#
#                                                    method extrapolation  \
# 147001  We extrapolate the PPP from the latest ICP (20...           NaN
# 147002  We extrapolate the PPP from the latest ICP (20...           NaN
# 147003  We extrapolate the PPP from the latest ICP (20...           NaN
# 147004  We extrapolate the PPP from the latest ICP (20...           NaN
# 147005  We extrapolate the PPP from the latest ICP (20...           NaN
# 147006  We extrapolate the PPP from the latest ICP (20...           NaN
# 147007  We extrapolate the PPP from the latest ICP (20...           NaN
# 147008  We extrapolate the PPP from the latest ICP (20...           NaN
# 147009  We extrapolate the PPP from the latest ICP (20...           NaN
# 147010  We extrapolate the PPP from the latest ICP (20...           NaN
# 147011  We extrapolate the PPP from the latest ICP (20...           NaN
# 147012  We extrapolate the PPP from the latest ICP (20...           NaN
# 147013  We extrapolate the PPP from the latest ICP (20...           NaN
# 147014  We extrapolate the PPP from the latest ICP (20...           NaN
# 147015  We extrapolate the PPP from the latest ICP (20...           NaN
# 147016  We extrapolate the PPP from the latest ICP (20...           NaN
# 147017  We extrapolate the PPP from the latest ICP (20...           NaN
# 147018  We extrapolate the PPP from the latest ICP (20...           NaN
# 147019  We extrapolate the PPP from the latest ICP (20...           NaN
# 147020  We extrapolate the PPP from the latest ICP (20...           NaN
# 147021  We extrapolate the PPP from the latest ICP (20...           NaN
# 147022  We extrapolate the PPP from the latest ICP (20...           NaN
# 147023  We extrapolate the PPP from the latest ICP (20...           NaN
# 147024  We extrapolate the PPP from the latest ICP (20...           NaN
# 147025  We extrapolate the PPP from the latest ICP (20...           NaN
# 147026  We extrapolate the PPP from the latest ICP (20...           NaN
# 147027  We extrapolate the PPP from the latest ICP (20...           NaN
# 147028  We extrapolate the PPP from the latest ICP (20...           NaN
# 147029  We extrapolate the PPP from the latest ICP (20...           NaN
# 147030  We extrapolate the PPP from the latest ICP (20...           NaN
# 147031  We extrapolate the PPP from the latest ICP (20...           NaN
# 147032  We extrapolate the PPP from the latest ICP (20...           NaN
# 147033  We extrapolate the PPP from the latest ICP (20...           NaN
# 147034  We extrapolate the PPP from the latest ICP (20...           NaN
# 147035  We extrapolate the PPP from the latest ICP (20...           NaN
# 147036  We extrapolate the PPP from the latest ICP (20...           NaN
# 147037  We extrapolate the PPP from the latest ICP (20...           NaN
# 147038  We extrapolate the PPP from the latest ICP (20...           NaN
# 147039  We extrapolate the PPP from the latest ICP (20...           NaN
# 147040  We extrapolate the PPP from the latest ICP (20...           NaN
# 147041  We extrapolate the PPP from the latest ICP (20...           NaN
# 147042  We extrapolate the PPP from the latest ICP (20...           NaN
# 147043  We extrapolate the PPP from the latest ICP (20...           NaN
# 147044  We extrapolate the PPP from the latest ICP (20...           NaN
# 147045  We extrapolate the PPP from the latest ICP (20...           NaN
# 147046  We extrapolate the PPP from the latest ICP (20...           NaN
# 147047  We extrapolate the PPP from the latest ICP (20...           NaN
# 147048  We extrapolate the PPP from the latest ICP (20...           NaN
# 147049  We extrapolate the PPP from the latest ICP (20...           NaN
# 147050  We extrapolate the PPP from the latest ICP (20...           NaN
# 147051  We extrapolate the PPP from the latest ICP (20...           NaN
# 147052  We extrapolate the PPP from the latest ICP (20...           NaN
# 147053  We extrapolate the PPP from the latest ICP (20...           NaN
# 147054  We extrapolate the PPP from the latest ICP (20...           NaN
#
#        data_points
# 147001         NaN
# 147002         NaN
# 147003         NaN
# 147004         NaN
# 147005         NaN
# 147006         NaN
# 147007         NaN
# 147008         NaN
# 147009         NaN
# 147010         NaN
# 147011         NaN
# 147012         NaN
# 147013         NaN
# 147014         NaN
# 147015         NaN
# 147016         NaN
# 147017         NaN
# 147018         NaN
# 147019         NaN
# 147020         NaN
# 147021         NaN
# 147022         NaN
# 147023         NaN
# 147024         NaN
# 147025         NaN
# 147026         NaN
# 147027         NaN
# 147028         NaN
# 147029         NaN
# 147030         NaN
# 147031         NaN
# 147032         NaN
# 147033         NaN
# 147034         NaN
# 147035         NaN
# 147036         NaN
# 147037         NaN
# 147038         NaN
# 147039         NaN
# 147040         NaN
# 147041         NaN
# 147042         NaN
# 147043         NaN
# 147044         NaN
# 147045         NaN
# 147046         NaN
# 147047         NaN
# 147048         NaN
# 147049         NaN
# 147050         NaN
# 147051         NaN
# 147052         NaN
# 147053         NaN
# 147054         NaN
#
# [54 rows x 24 columns]
